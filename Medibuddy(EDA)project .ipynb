# %% [markdown]
# # **Project Name**    - Medibuddy Project
#
#
#
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The MediBuddy Capstone Project focuses on analyzing healthcare insurance data to identify key factors influencing insurance claims and policy decisions. Using Python and exploratory data analysis techniques, the project combines personal health details and insurance pricing data to uncover meaningful patterns related to age, BMI, smoking habits, dependents, gender, and geographic location.
#
# The analysis aims to support data-driven decision-making for insurance policy extension, pricing optimization, risk assessment, and customer segmentation. Visualizations and statistical insights were used to translate raw data into actionable business insights for MediBuddy.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1. To analyze whether the gender of an individual has a significant impact on insurance policy extension and claim amounts.
#
# 2. To determine the average amount of money spent by the company on each insurance policy cover.
#
# 3. To evaluate whether geographic location plays a role in deciding insurance policy pricing and claim behavior.
#
# 4. To examine the impact of the number of dependents on the total insurance amount claimed.
#
# 5. To analyze the relationship between Body Mass Index (BMI) and insurance claims in order to understand health-related risk patterns.
#
# 6. To assess whether smoking status (smoker or non-smoker) significantly influences insurance claim amounts.
#
# 7. To study the effect of age on insurance claims and determine if age acts as a barrier in policy pricing or claim amount.
#
# 8. To evaluate whether insurance discounts can be offered based on the health status of individuals, specifically using BMI as a health indicator.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here:
# The primary business objectives of this project are:
#
# 1. To identify key factors that influence insurance claim amounts
# 2. To evaluate whether demographic and lifestyle attributes impact policy pricing
# 3. To understand health-related risk indicators such as BMI, age, and smoking status
# 4. To support MediBuddy in making data-driven decisions for policy extension, pricing, and discounts

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df1 = pd.read_excel("Medibuddy personal details.xlsx")
df2 = pd.read_excel("Medibuddy Data Price.xlsx")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head()
# Out:
#   Policy no.  children smoker     region
# 0  PLC157006         0     no  southwest
# 1  PLC157033         1     no  southwest
# 2  PLC157060         0     no  southwest
# 3  PLC157087         1     no  southwest
# 4  PLC157186         5     no  southwest

# %%
df2.head()
# Out:
#   Policy no.  age     sex     bmi  charges in INR
# 0  PLC156898   19  female  27.900     16884.92400
# 1  PLC156907   18    male  33.770      1725.55230
# 2  PLC156916   28    male  33.000      4449.46200
# 3  PLC156925   33    male  22.705     21984.47061
# 4  PLC156934   32    male  28.880      3866.85520

# %%
#Checking Data-types
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Policy no.  1338 non-null   object
#  1   children    1338 non-null   int64
#  2   smoker      1338 non-null   object
#  3   region      1338 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 41.9+ KB

# %%
#Checking Data-types
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Policy no.      1338 non-null   object
#  1   age             1338 non-null   int64
#  2   sex             1338 non-null   object
#  3   bmi             1338 non-null   float64
#  4   charges in INR  1338 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 52.4+ KB

# %%
#Renaming the column name
new_col = {'charges in INR':'Charges'}
df2.rename(columns=new_col,inplace= True)
print(df2)
# Out:
#      Policy no.  age     sex     bmi      Charges
# 0     PLC156898   19  female  27.900  16884.92400
# 1     PLC156907   18    male  33.770   1725.55230
# 2     PLC156916   28    male  33.000   4449.46200
# 3     PLC156925   33    male  22.705  21984.47061
# 4     PLC156934   32    male  28.880   3866.85520
# ...         ...  ...     ...     ...          ...
# 1333  PLC168895   50    male  30.970  10600.54830
# 1334  PLC168904   18  female  31.920   2205.98080
# 1335  PLC168913   18  female  36.850   1629.83350
# 1336  PLC168922   21  female  25.800   2007.94500
# 1337  PLC168931   61  female  29.070  29141.36030
#
# [1338 rows x 5 columns]

# %%
#Changing data-types
df2['Charges']=df2['Charges'].astype(int)
print(df2.dtypes)
# Out:
# Policy no.     object
# age             int64
# sex            object
# bmi           float64
# Charges         int32
# dtype: object

# %%
df2.head()
# Out:
#   Policy no.  age     sex     bmi  Charges
# 0  PLC156898   19  female  27.900    16884
# 1  PLC156907   18    male  33.770     1725
# 2  PLC156916   28    male  33.000     4449
# 3  PLC156925   33    male  22.705    21984
# 4  PLC156934   32    male  28.880     3866

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df1.shape
# Out:
# (1338, 4)

# %%
df2.shape
# Out:
# (1338, 5)

# %% [markdown]
# ### Dataset Information

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Policy no.  1338 non-null   object
#  1   children    1338 non-null   int64
#  2   smoker      1338 non-null   object
#  3   region      1338 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 41.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Policy no.  1338 non-null   object
#  1   age         1338 non-null   int64
#  2   sex         1338 non-null   object
#  3   bmi         1338 non-null   float64
#  4   Charges     1338 non-null   int32
# dtypes: float64(1), int32(1), int64(1), object(2)
# memory usage: 47.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
df1['Policy no.'].duplicated().sum()
# Out:
# 0

# %%
df2['Policy no.'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
df1.isnull().sum()
# Out:
# Policy no.    0
# children      0
# smoker        0
# region        0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Policy no.    0
# age           0
# sex           0
# bmi           0
# Charges       0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here: There were two datasets first one shows the personal details of the person and the second one shows the data prices based on the policy number.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df1.columns
# Out:
# Index(['Policy no.', 'children', 'smoker', 'region'], dtype='object')

# %%
df2.columns
# Out:
# Index(['Policy no.', 'age', 'sex', 'bmi', 'Charges'], dtype='object')

# %%
df1.describe()
# Out:
#           children
# count  1338.000000
# mean      1.094918
# std       1.205493
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       5.000000

# %%
df2.describe()
# Out:
#                age          bmi       Charges
# count  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397  13269.928999
# std      14.049960     6.098187  12110.012755
# min      18.000000    15.960000   1121.000000
# 25%      27.000000    26.296250   4740.000000
# 50%      39.000000    30.400000   9381.500000
# 75%      51.000000    34.693750  16639.250000
# max      64.000000    53.130000  63770.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here: So here the average age is seen to be 39 years and the count of children having by each individual is approx 1 also the BMI measures is average of 30 and for it the Charges are 13000 approx.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df1.nunique()
# Out:
# Policy no.    1338
# children         6
# smoker           2
# region           4
# dtype: int64

# %%
df2.nunique()
# Out:
# Policy no.    1338
# age             47
# sex              2
# bmi            548
# Charges       1284
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#Merging both datasets
df=pd.merge(df1,df2,on='Policy no.',how='inner')
df.head()
# Out:
#   Policy no.  children smoker     region  age     sex   bmi  Charges
# 0  PLC157006         0     no  southwest   23    male  34.4     1826
# 1  PLC157033         1     no  southwest   19    male  24.6     1837
# 2  PLC157060         0     no  southwest   56    male  40.3    10602
# 3  PLC157087         1     no  southwest   30  female  32.4     4149
# 4  PLC157186         5     no  southwest   19  female  28.6     4687

# %%
df['policy type']=df['children'].apply(lambda x:'Individual'if x==0 else 'Family')

# %%
df.head()
# Out:
#   Policy no.  children smoker     region  age     sex   bmi  Charges  \
# 0  PLC157006         0     no  southwest   23    male  34.4     1826
# 1  PLC157033         1     no  southwest   19    male  24.6     1837
# 2  PLC157060         0     no  southwest   56    male  40.3    10602
# 3  PLC157087         1     no  southwest   30  female  32.4     4149
# 4  PLC157186         5     no  southwest   19  female  28.6     4687
#
#   policy type
# 0  Individual
# 1      Family
# 2  Individual
# 3      Family
# 4      Family

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (1338, 9)

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Policy no.   1338 non-null   object
#  1   children     1338 non-null   int64
#  2   smoker       1338 non-null   object
#  3   region       1338 non-null   object
#  4   age          1338 non-null   int64
#  5   sex          1338 non-null   object
#  6   bmi          1338 non-null   float64
#  7   Charges      1338 non-null   int32
#  8   policy type  1338 non-null   object
# dtypes: float64(1), int32(1), int64(2), object(5)
# memory usage: 89.0+ KB

# %%
# Dataset Duplicate Value Count
df['Policy no.'].duplicated().sum()
# Out:
# 0

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Policy no.     0
# children       0
# smoker         0
# region         0
# age            0
# sex            0
# bmi            0
# Charges        0
# policy type    0
# dtype: int64

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Policy no.', 'children', 'smoker', 'region', 'age', 'sex', 'bmi',
#        'Charges', 'policy type'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#           children          age          bmi       Charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean      1.094918    39.207025    30.663397  13269.928999
# std       1.205493    14.049960     6.098187  12110.012755
# min       0.000000    18.000000    15.960000   1121.000000
# 25%       0.000000    27.000000    26.296250   4740.000000
# 50%       1.000000    39.000000    30.400000   9381.500000
# 75%       2.000000    51.000000    34.693750  16639.250000
# max       5.000000    64.000000    53.130000  63770.000000

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# Policy no.     1338
# children          6
# smoker            2
# region            4
# age              47
# sex               2
# bmi             548
# Charges        1284
# policy type       2
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here: So i have merged the two datasets based on the common column and from dataset two i have renamed one column name('Charges') found out the average age, average charges etc.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
df.groupby('sex')['Charges'].mean()
# Out:
# sex
# female    12569.069486
# male      13956.273669
# Name: Charges, dtype: float64

# %%
a=sns.barplot(x='sex',y='Charges',data=df)
a.bar_label(a.containers[0])
plt.title("Average Insurance Charges by Gender")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Because i need to know that do males and females claim different insurance amounts?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:Average charges for males and females are similar, indicating gender alone should not be a constraint for extending policies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between the gender insurance amounts is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
df['Charges'].mean()
# Out:
# 13269.928998505231

# %%
df.groupby('policy type')['Charges'].mean()
# Out:
# policy type
# Family        13949.463351
# Individual    12365.461672
# Name: Charges, dtype: float64

# %%
b=sns.barplot(x='policy type',y='Charges',data=df)
b.bar_label(b.containers[0])
plt.title("Average charges on policy type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see on average, how much money does MediBuddy spend per policy?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Helps MediBuddy understand average claim exposure per policy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between the policy type insurance amounts is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
df.groupby('region')['Charges'].mean().sort_values(ascending= False)
# Out:
# region
# southeast    14734.903846
# northeast    13405.910494
# northwest    12417.070769
# southwest    12346.452308
# Name: Charges, dtype: float64

# %%
sns.boxplot(x='region',y='Charges',data=df)
plt.xticks(rotation=35)
plt.title('Average charges by region')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see people from different regions claim different amounts?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Certain regions show higher claim amounts - region-based pricing can be considered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between the regions insurance amounts is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
df.groupby('children')['Charges'].mean()
# Out:
# children
# 0    12365.461672
# 1    12730.706790
# 2    15073.066667
# 3    15354.847134
# 4    13850.200000
# 5     8785.500000
# Name: Charges, dtype: float64

# %%
sns.lineplot(x='children',y='Charges',data=df)
plt.title('Average charge by children')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see If a person has more children, does insurance cost increase?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: More dependents - higher average claims - risk increases with dependents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence if a person has more children, does insurance cost increase is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
df['bmi category']=pd.cut(df['bmi'],bins=[0,18.5,24.9,29.9,100],labels=['Underweight','Normal','Overweight','Obese'])

# %%
df.groupby('bmi category')['Charges'].mean()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_60068\647182871.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('bmi category')['Charges'].mean()
# bmi category
# Underweight     8657.142857
# Normal         10404.389140
# Overweight     11006.305263
# Obese          15491.060056
# Name: Charges, dtype: float64

# %%
c=sns.barplot(x='bmi category',y='Charges',data=df)
c.bar_label(c.containers[0])
plt.title("Average bmi category claim charges ")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To check overweight or unhealthy people claim more money?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:Obese individuals tend to have higher claim amounts

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between average bmi category claim money is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
df.groupby('smoker')['Charges'].mean()
# Out:
# smoker
# no      8433.778195
# yes    32049.726277
# Name: Charges, dtype: float64

# %%
sns.boxplot(x='smoker',y='Charges',data=df)
plt.title('Average charges of smoker/no smoker')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To check smokers cost more money than non-smokers?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Smokers have significantly higher claims - smoking status must be considered in policy pricing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between average cost of smoker and no smoker is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
df.groupby('age')['Charges'].mean()
# Out:
# age
# 18     7085.710145
# 19     9747.367647
# 20    10159.241379
# 21     4730.000000
# 22    10012.392857
# 23    12419.392857
# 24    10647.428571
# 25     9837.857143
# 26     6133.321429
# 27    12184.107143
# 28     9068.678571
# 29    10429.629630
# 30    12718.666667
# 31    10196.555556
# 32     9219.807692
# 33    12351.038462
# 34    11613.000000
# 35    11306.760000
# 36    12204.080000
# 37    18019.360000
# 38     8102.200000
# 39    11777.800000
# 40    11771.740741
# 41     9653.259259
# 42    13060.555556
# 43    19266.888889
# 44    15858.925926
# 45    14829.689655
# 46    14342.103448
# 47    17653.482759
# 48    14632.137931
# 49    12695.464286
# 50    15662.551724
# 51    15681.862069
# 52    18255.655172
# 53    16020.357143
# 54    18758.035714
# 55    16164.038462
# 56    15025.153846
# 57    16446.769231
# 58    13878.400000
# 59    18895.280000
# 60    21978.826087
# 61    22024.043478
# 62    19163.391304
# 63    19884.478261
# 64    23275.045455
# ...

# %%
sns.scatterplot(x='age',y='Charges',data=df)
plt.title('Average age charges')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.To check older people claim more than younger people?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:Claim amount generally increases with age - higher age = higher risk exposure.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between average cost for age  is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
sns.scatterplot(x='bmi', y='Charges', data=df)
plt.title('BMI vs Insurance Charges')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To check, Can healthy people (normal BMI) get discounts?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Insurance charges increase as BMI increases, indicating BMI is a strong predictor of health-related costs

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between bmi vs charges is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
df['age groups']=pd.cut(df['age'],bins=[18,30,45,60,100],labels=['18-30','31-45','46-60','60+'])

# %%
d=sns.barplot(x='age groups',y='Charges',data=df)
d.bar_label(d.containers[0])
plt.title('Average Insurance Charges by Age Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:To see Age groups show clear risk bands.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:Insurance risk increases significantly after age 45.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between age groups is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
sns.barplot(x='bmi category',y='Charges',hue='smoker',data=df)
plt.title('BMI vs Charges by Smoking Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here:To see combined risk

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:Smokers with high BMI show extremely high insurance costs

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between smoker and no smoker is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
sns.boxplot(x='children',y='Charges',data=df)
plt.title('Insurance charges based on children')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see the differences, spread, and inconsistencies between charges

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: More dependents increase claim variability and financial risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between charges by children is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
e=sns.barplot(x='sex',y='Charges',hue='smoker',data=df)
plt.title('Gender and Smoking impact on charges')
e.bar_label(e.containers[0])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see how much domination is there from smoking gender wise

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Smoking status dominates gender in determining risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between smokers by gender is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
sns.histplot(df['Charges'],bins=30,kde=True)
plt.title('Distribution of Insurance Charges')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see the actual distribution count based on charges

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:Most customers have low charges, while few incur very high costs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here:Yes sure the gained insights will definately help to create positive bussiness impact because the diffrence between the count of charges is clearly describe in the above chart.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
corr=df[['age','bmi','children','Charges']].corr()
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title("Correlation between numerical features")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.To understand the correlation between variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: Age and BMI have stronger correlation with charges than children.

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code
df['high risk']=np.where((df['smoker']=='yes')&(df['bmi']>=30)&(df['age']>45),'High risk','Low risk')
h=sns.countplot(x='high risk',data=df)
plt.title('High risk vs Low risk customers')
h.bar_label(h.containers[0])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here: To see the actual risk segmentation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here: A small portion of customers contribute to high insurance risk.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here:
#
# 1. Gender was found to have minimal impact on insurance charges, indicating it should not be a major constraint in extending insurance policies.
#
# 2. The average insurance amount spent per policy provides a benchmark for understanding MediBuddy’s overall financial exposure and helps in policy pricing strategy.
#
# 3. Geographic location showed noticeable variation in claim amounts, suggesting that region-based policy customization and pricing can be considered.
#
# 4. Customers with a higher number of childrens tend to incur higher insurance claims, indicating increased financial risk for the insurer.
#
# 5. BMI analysis revealed that individuals in the overweight and obese categories have significantly higher claim amounts, making BMI a strong indicator of health risk.
#
# 6. Smoking status has a major impact on insurance claims, with smokers incurring substantially higher costs compared to non-smokers.
#
# 7. Customers with a normal BMI represent lower health risk and can be rewarded with premium discounts, encouraging healthier lifestyles and preventive care.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This analysis helped MediBuddy identify key factors such as smoking status, BMI, age, and dependents that significantly impact insurance claims. Gender alone was found to have minimal impact. The insights can be used to optimize policy pricing, introduce health-based discounts, and manage risk efficiently.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
